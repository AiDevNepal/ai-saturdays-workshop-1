# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/asish/machine-learning/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Generate dataset
trX = np.linspace(-1, 1, 101)
#trX =   (trX - np.min(trX)) / (np.max(trX) - np.min(trX))
#print(trX)

# %%
noise = np.random.randn(*trX.shape) * 0.33

# %%
plt.plot(trX)

# %%
plt.plot(noise)

# %%
trY = 2 * trX + noise# create a y value which is approximately linear but with some random noise
plt.plot(trY)

# %%
noise
# Out:
# array([ 7.67161225e-03, -1.51701305e-01,  1.77964293e-02,  7.45616059e-02,
#         3.45119727e-01, -4.52033449e-02, -4.64480206e-01,  7.13953377e-02,
#         2.36566923e-01,  1.25984162e-01, -4.56629876e-01, -7.31408026e-01,
#        -6.48782089e-02,  3.25917029e-01, -6.79590946e-03,  4.73335682e-01,
#        -9.98774672e-02,  5.02400535e-02, -5.69548624e-01,  5.45317808e-01,
#         2.09139033e-01,  1.56563949e-01,  4.43063551e-01, -5.85331167e-01,
#        -6.33950738e-02,  7.56114593e-02,  2.21238360e-01, -7.64992862e-02,
#        -7.22912032e-02, -5.91070955e-01,  4.15692827e-01,  6.07990848e-02,
#        -1.83056565e-01, -4.33457801e-01,  1.26384967e-01, -6.13413991e-02,
#         3.13747521e-02, -1.25575657e-01,  9.48155866e-02,  1.02779801e-01,
#         4.63279397e-01, -3.11188735e-02,  6.81544929e-01, -4.21713025e-01,
#        -7.17601567e-02,  1.57191560e-02,  3.74884951e-01, -7.55347019e-01,
#         7.48140138e-02,  3.51378137e-01,  3.73493802e-01, -3.32371397e-01,
#         2.35114865e-01, -5.22382207e-02,  2.70680840e-01,  2.55568852e-01,
#         1.48686986e-01, -4.53031027e-01, -4.17059908e-01, -7.95555649e-02,
#        -4.75054204e-01,  3.42064630e-04, -9.07455308e-02, -8.33233967e-01,
#        -3.62208599e-01,  1.00335028e+00,  2.10797374e-01, -4.40216132e-02,
#         8.09356695e-01,  5.50518826e-01, -5.60312337e-01,  4.03182391e-01,
#         1.90098622e-01, -2.33658409e-01, -4.08604791e-02,  2.63246500e-01,
#         2.37107392e-01,  3.80803499e-01,  7.89439575e-01, -1.24634787e-01,
#        -6.20891030e-02, -1.43900617e-02, -8.33997319e-02, -2.05061242e-01,
#        -3.71495452e-01,  3.47911176e-01, -6.61617689e-01,  2.47686914e-01,
#         6.73425217e-02,  4.84754534e-01, -9.15465375e-01,  2.32921045e-01,
#        -3.39810800e-01, -2.17956079e-02,  1.55489422e-01,  1.77001189e-01,
#        -5.03151027e-01,  3.53551423e-01, -2.10064998e-01,  9.91185342e-02,
#        -2.27868836e-01])

# %%
model = Sequential()
model.add(Dense(input_dim=1, output_dim=1, init='uniform',activation='linear'))
model.compile(optimizer='sgd', loss='mse')
# Out:
# /home/asish/machine-learning/lib/python3.5/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="linear", units=1, input_dim=1, kernel_initializer="uniform")`

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Print initial weights
weights = model.layers[0].get_weights()
print(weights)
w_init = weights[0][0][0]
b_init = weights[1][0]
print('Linear regression model is initialized with weight w: %.2f, b: %.2f' % (w_init, b_init))
# Out:
# [array([[-0.03987575]], dtype=float32), array([0.], dtype=float32)]
# Linear regression model is initialized with weight w: -0.04, b: 0.00

# %%
from keras.callbacks import TensorBoard
tensorboard = TensorBoard(log_dir='./logs', histogram_freq=0,
                          write_graph=True, write_images=False)

# %%
model.fit(trX,trY,nb_epoch=100,verbose=1,callbacks=[tensorboard])
# Out:
# Epoch 1/100
# 101/101 [==============================] - 0s 174us/step - loss: 1.5325
# Epoch 2/100
# 101/101 [==============================] - 0s 82us/step - loss: 1.4556
# Epoch 3/100
#  32/101 [========>.....................] - ETA: 0s - loss: 1.6015
# /home/asish/machine-learning/lib/python3.5/site-packages/keras/models.py:944: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# 101/101 [==============================] - 0s 107us/step - loss: 1.3872
# Epoch 4/100
# 101/101 [==============================] - 0s 110us/step - loss: 1.3146
# Epoch 5/100
# 101/101 [==============================] - 0s 117us/step - loss: 1.2546
# Epoch 6/100
# 101/101 [==============================] - 0s 103us/step - loss: 1.1930
# Epoch 7/100
# 101/101 [==============================] - 0s 91us/step - loss: 1.1230
# Epoch 8/100
# 101/101 [==============================] - 0s 90us/step - loss: 1.0742
# Epoch 9/100
# 101/101 [==============================] - 0s 76us/step - loss: 1.0319
# Epoch 10/100
# 101/101 [==============================] - 0s 73us/step - loss: 0.9832
# Epoch 11/100
# 101/101 [==============================] - 0s 65us/step - loss: 0.9286
# Epoch 12/100
# 101/101 [==============================] - 0s 77us/step - loss: 0.8838
# Epoch 13/100
# 101/101 [==============================] - 0s 87us/step - loss: 0.8487
# Epoch 14/100
# 101/101 [==============================] - 0s 63us/step - loss: 0.8103
# Epoch 15/100
# 101/101 [==============================] - 0s 67us/step - loss: 0.7775
# Epoch 16/100
# 101/101 [==============================] - 0s 89us/step - loss: 0.7434
# Epoch 17/100
# 101/101 [==============================] - 0s 96us/step - loss: 0.7128
# Epoch 18/100
# 101/101 [==============================] - 0s 78us/step - loss: 0.6783
# Epoch 19/100
# 101/101 [==============================] - 0s 80us/step - loss: 0.6529
# Epoch 20/100
# 101/101 [==============================] - 0s 62us/step - loss: 0.6284
# Epoch 21/100
# 101/101 [==============================] - 0s 72us/step - loss: 0.5979
# Epoch 22/100
# 101/101 [==============================] - 0s 87us/step - loss: 0.5701
# Epoch 23/100
# 101/101 [==============================] - 0s 102us/step - loss: 0.5417
# Epoch 24/100
# 101/101 [==============================] - 0s 77us/step - loss: 0.5208
# Epoch 25/100
# 101/101 [==============================] - 0s 118us/step - loss: 0.5000
# Epoch 26/100
# 101/101 [==============================] - 0s 63us/step - loss: 0.4800
# Epoch 27/100
# 101/101 [==============================] - 0s 108us/step - loss: 0.4640
# Epoch 28/100
# 101/101 [==============================] - 0s 99us/step - loss: 0.4480
# Epoch 29/100
# 101/101 [==============================] - 0s 107us/step - loss: 0.4317
# Epoch 30/100
# 101/101 [==============================] - 0s 87us/step - loss: 0
100
# 101/101 [==============================] - 0s 87us/step - loss: 0.1626
# Epoch 73/100
# 101/101 [==============================] - 0s 70us/step - loss: 0.1608
# Epoch 74/100
# 101/101 [==============================] - 0s 66us/step - loss: 0.1591
# Epoch 75/100
# 101/101 [==============================] - 0s 63us/step - loss: 0.1578
# Epoch 76/100
# 101/101 [==============================] - 0s 70us/step - loss: 0.1568
# Epoch 77/100
# 101/101 [==============================] - 0s 73us/step - loss: 0.1559
# Epoch 78/100
# 101/101 [==============================] - 0s 115us/step - loss: 0.1545
# Epoch 79/100
# 101/101 [==============================] - 0s 100us/step - loss: 0.1532
# Epoch 80/100
# 101/101 [==============================] - 0s 91us/step - loss: 0.1519
# Epoch 81/100
# 101/101 [==============================] - 0s 66us/step - loss: 0.1507
# Epoch 82/100
# 101/101 [==============================] - 0s 79us/step - loss: 0.1498
# Epoch 83/100
# 101/101 [==============================] - 0s 69us/step - loss: 0.1488
# Epoch 84/100
# 101/101 [==============================] - 0s 66us/step - loss: 0.1477
# Epoch 85/100
# 101/101 [==============================] - 0s 67us/step - loss: 0.1470
# Epoch 86/100
# 101/101 [==============================] - 0s 65us/step - loss: 0.1458
# Epoch 87/100
# 101/101 [==============================] - 0s 72us/step - loss: 0.1449
# Epoch 88/100
# 101/101 [==============================] - 0s 119us/step - loss: 0.1444
# Epoch 89/100
# 101/101 [==============================] - 0s 120us/step - loss: 0.1438
# Epoch 90/100
# 101/101 [==============================] - 0s 134us/step - loss: 0.1437
# Epoch 91/100
# 101/101 [==============================] - 0s 81us/step - loss: 0.1426
# Epoch 92/100
# 101/101 [==============================] - 0s 78us/step - loss: 0.1423
# Epoch 93/100
# 101/101 [==============================] - 0s 73us/step - loss: 0.1418
# Epoch 94/100
# 101/101 [==============================] - 0s 65us/step - loss: 0.1411
# Epoch 95/100
# 101/101 [==============================] - 0s 69us/step - loss: 0.1405
# Epoch 96/100
# 101/101 [==============================] - 0s 76us/step - loss: 0.1402
# Epoch 97/100
# 101/101 [==============================] - 0s 82us/step - loss: 0.1396
# Epoch 98/100
# 101/101 [==============================] - 0s 87us/step - loss: 0.1394
# Epoch 99/100
# 101/101 [==============================] - 0s 88us/step - loss: 0.1386
# Epoch 100/100
# 101/101 [==============================] - 0s 76us/step - loss: 0.1383

# %%
weights = model.layers[0].get_weights()
w = weights[0][0][0]
b = weights[1][0]
print('Linear regression model is trained with weight w: %.2f, b: %.2f' % (w, b))
# Out:
# Linear regression model is trained with weight w: 1.87, b: 0.00

# %%
plt.plot(trX, trY, label='data')
plt.plot(trX, w_init*trX + b_init, label='init')
plt.plot(trX, w*trX + b, label='prediction')
plt.legend()
plt.show()

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png',show_shapes='True') # to save above
